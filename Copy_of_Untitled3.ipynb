# %% [markdown]
# <a href="https://colab.research.google.com/github/GaniyevHamidullo/CompilerAI/blob/main/Copy_of_Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 google.colab  dan import  drive
drive.mount( '/content/drive' )
# Out:
#   File "/tmp/ipython-input-2-3023507452.py", line 1
#     google.colab  dan import  drive
#                   ^
# SyntaxError: invalid syntax

# %%
 matplotlib.pyplot ni   plot sifatida import qilish
plot.plot([ 2 , 5 , 7 , 9 , 11 ])
plot.show()
